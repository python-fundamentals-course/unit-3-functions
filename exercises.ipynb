# %% [markdown]
# # Unit 3: Functions & Code Organisation — Exercises
#
# > **Python Fundamentals**
#
# Complete the reading materials, curated videos, and `notebook.ipynb` before working through these exercises.

# %% [markdown]
# ## Learning objectives
#
# By the end of this unit you will be able to:
#
# - Identify when a block of code should become a function
# - Write functions with parameters, default values, and return values
# - Refactor a procedural script into a modular structure

# %% [markdown]
# ## Exercise 1: Function with a default parameter
#
# Write a function `apply_discount(price, discount_rate=0.10)` that returns the discounted price (`price - price * discount_rate`).
#
# Test it with:
#
# 1. `apply_discount(100)` (using the default 10% discount)
# 2. `apply_discount(100, discount_rate=0.25)` (a 25% discount)
#
# Print both results.

# %%
# TODO: define apply_discount(price, discount_rate=0.10)


# TODO: test with the default rate and a 25% rate

# %% [markdown]
# ## Exercise 2: Function returning multiple values
#
# Write a function `analyse_scores(scores)` that takes a list of numbers and returns a tuple of `(highest, lowest, average)`.
#
# Test it on `[72, 88, 91, 65, 79]` and print all three values.

# %%
scores = [72, 88, 91, 65, 79]

# TODO: define analyse_scores(scores) returning (highest, lowest, average)


# TODO: call it and print the results

# %% [markdown]
# ## Exercise 3: Refactor repeated code
#
# The code below calculates the area and perimeter of three rectangles, repeating the same formulas each time. Refactor it by writing two functions, `area(width, height)` and `perimeter(width, height)`, then rewrite the loop to use them.

# %%
rectangles = [
    {"name": "A", "width": 4, "height": 3},
    {"name": "B", "width": 10, "height": 2},
    {"name": "C", "width": 5, "height": 5},
]

# TODO: define area(width, height)


# TODO: define perimeter(width, height)


# TODO: loop over rectangles, printing name, area, and perimeter for each

# %% [markdown]
# ## Exercise 4: Composing functions
#
# Using your `apply_discount` function from Exercise 1, write a new function `add_gst(price, gst_rate=0.09)` that returns `price + price * gst_rate`.
#
# Then write `final_price(price, discount_rate=0.10, gst_rate=0.09)` that:
#
# 1. Applies the discount first (using `apply_discount`)
# 2. Then adds GST to the discounted price (using `add_gst`)
# 3. Returns the final price
#
# Test `final_price(200)` and print the result.

# %%
def apply_discount(price, discount_rate=0.10):
    return price - price * discount_rate


# TODO: define add_gst(price, gst_rate=0.09)


# TODO: define final_price(price, discount_rate=0.10, gst_rate=0.09)
# using apply_discount and add_gst


# TODO: test final_price(200) and print it

# %% [markdown]
# ## Done?
#
# Run the tests (`pytest tests/ -v`) to check whether your answer is correct. Your solution doesn't need to match any particular approach, as long as it produces the right results — your trainer can walk through worked solutions in class.
